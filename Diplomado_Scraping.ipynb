# %% [markdown]
# <a href="https://colab.research.google.com/github/xkrizthx/Python/blob/python/Diplomado_Scraping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install beautifulsoup4
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
pip install lxml
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
pip install requests
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import bs4
import lxml
import requests

resultado=requests.get('https://escueladirecta-blog.blogspot.com/BLOG/26007/encapsulamiento')

# %%
print(type(resultado))
# Out:
# <class 'requests.models.Response'>

# %%
print(resultado.text)

# %%
import bs4
sopa=bs4.BeautifulSoup(resultado.text,'lxml')
print(sopa)

# %%
print(sopa.select('title')[0].getText())
# Out:
# Escuela Directa | Blog

# %%
print(sopa.select('div'))

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
columna=sopa.select('.content')
print(columna)
# Out:
# []

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from bs4 import BeautifulSoup
contenido ="""
<html lang="es">
<head>
    <meta charset="UTF-8">
    <title>Página de prueba</title>
</head>
<body>
<div id="main" class="full-width">
    <h1>El título de la página</h1>
    <p>Este es el primer párrafo de prueba</p>
    <p id="segundo">Este es el segundo párrafo de prueba</p>
    ...
</div>
</body>
</html>
"""
soup=BeautifulSoup(contenido,'lxml')

# %%
soup.title
# Out:
# <title>Página de prueba</title>

# %%
print(soup.select('title')[0].getText())
# Out:
# Página de prueba

# %%
variable=soup.title
print(variable)
# Out:
# <title>Página de prueba</title>

# %%
captura_div=soup.div
print(captura_div)
# Out:
# <div class="full-width" id="main">
# <h1>El título de la página</h1>
# <p>Este es el primer párrafo de prueba</p>
# <p>Este es el segundo párrafo de prueba</p>
#     ...
# </div>

# %%
print(captura_div['id'])
# Out:
# main

# %%
print(captura_div.attrs)
# Out:
# {'id': 'main', 'class': ['full-width']}

# %%
captura_div=soup.div
print(captura_div['class'])
# Out:
# ['full-width']

# %%
captura_div=soup.div
print(captura_div['id'])
# Out:
# main

# %%
from bs4 import BeautifulSoup
contenido ="""
<html lang="es">
<head>
    <meta charset="UTF-8">
    <title>Página de prueba</title>
</head>
<body>
<div id="main" class="full-width">
    <h1>El título de la página</h1>
    <h2>Segundo título de la página</h2>
    <p>Este es el primer párrafo de prueba</p>
    <p>Este es el segundo párrafo de prueba</p>
    ...
</div>
</body>
</html>
"""
soup=BeautifulSoup(contenido,'lxml')

# %%
primer_parrafo=soup.p
print(primer_parrafo)
# Out:
# <p>Este es el primer párrafo de prueba</p>

# %%
print(primer_parrafo.string)
# Out:
# Este es el primer párrafo de prueba

# %%
primera_etiqueta=soup.h2
print(primera_etiqueta.string)
# Out:
# Segundo título de la página

# %%
print(soup.meta['charset'])
# Out:
# UTF-8

# %%
primera_etiqueta=soup.head
print(primera_etiqueta)
# Out:
# <head>
# <meta charset="utf-8"/>
# <title>Página de prueba</title>
# </head>

# %%
from bs4 import BeautifulSoup
contenido = """
<html lang="es">
<head>
    <meta charset="UTF-8">
    <title>Página de prueba</title>
</head>
<body>
<div id="main" class="full-width">
    <h1>El título de la página</h1>
    <p>Este es el primer párrafo</p>
    <p>Este es el segundo párrafo</p>
    <div id="innerDiv">
        <div class="links">
            <a href="https://pagina1.xyz/">Enlace 1</a>
            <a href="https://pagina2.xyz/">Enlace 2</a>
        </div>
        <div class="right">
            <div class="links">
                <a href="https://pagina3.xyz/">Enlace 3</a>
                <a href="https://pagina4.xyz/">Enlace 4</a>
                <p> Esto es un parrafo </p>
            </div>
        </div>
    </div>
    <div id="footer">
        <!-- El footer -->
        <p>Este párrafo está en el footer</p>
        <div class="links footer-links">
            <a href="https://pagina5.xyz/">Enlace 5</a>
        </div>
    </div>
</div>
</body>
</html>
"""
soup = BeautifulSoup(contenido, 'lxml')

# %%
div_adentro=soup.div.div.div
print(div_adentro)
# Out:
# <div class="links">
# <a href="https://pagina1.xyz/">Enlace 1</a>
# <a href="https://pagina2.xyz/">Enlace 2</a>
# </div>

# %%
print(div_adentro['class'])
# Out:
# ['links']

# %%
div_segundo=soup.div.div
print(div_segundo)
# Out:
# <div id="innerDiv">
# <div class="links">
# <a href="https://pagina1.xyz/">Enlace 1</a>
# <a href="https://pagina2.xyz/">Enlace 2</a>
# </div>
# <div class="right">
# <div class="links">
# <a href="https://pagina3.xyz/">Enlace 3</a>
# <a href="https://pagina4.xyz/">Enlace 4</a>
# </div>
# </div>
# </div>

# %%
hijos=div_segundo.contents
print(hijos)
# Out:
# ['\n', <div class="links">
# <a href="https://pagina1.xyz/">Enlace 1</a>
# <a href="https://pagina2.xyz/">Enlace 2</a>
# </div>, '\n', <div class="right">
# <div class="links">
# <a href="https://pagina3.xyz/">Enlace 3</a>
# <a href="https://pagina4.xyz/">Enlace 4</a>
# </div>
# </div>, '\n']

# %%
hijos=div_segundo.contents
print(hijos)
# Out:
# ['\n', <div class="links">
# <a href="https://pagina1.xyz/">Enlace 1</a>
# <a href="https://pagina2.xyz/">Enlace 2</a>
# </div>, '\n', <div class="right">
# <div class="links">
# <a href="https://pagina3.xyz/">Enlace 3</a>
# <a href="https://pagina4.xyz/">Enlace 4</a>
# </div>
# </div>, '\n']

# %%
for hijito in hijos:
  if hijito.name:
    print(f'{hijito.name}')
# Out:
# div
# div

# %%
inner_div=soup.div.div
print(inner_div)
# Out:
# <div id="innerDiv">
# <div class="links">
# <a href="https://pagina1.xyz/">Enlace 1</a>
# <a href="https://pagina2.xyz/">Enlace 2</a>
# </div>
# <div class="right">
# <div class="links">
# <a href="https://pagina3.xyz/">Enlace 3</a>
# <a href="https://pagina4.xyz/">Enlace 4</a>
# <p> Esto es un parrafo </p>
# </div>
# </div>
# </div>

# %%
hijos=inner_div.descendants
for child in hijos:
  if child.name:
    print(f'{child.name}')



#print(hijos)
# Out:
# div
# a
# a
# div
# div
# a
# a
# p

# %%
enlaces=soup.find_all('a')
print(enlaces[2].string)
# Out:
# Enlace 3

# %%
for enlace in enlaces:
  print(enlace.string)
# Out:
# Enlace 1
# Enlace 2
# Enlace 3
# Enlace 4
# Enlace 5

# %%
from bs4 import BeautifulSoup
contenido = """
<html lang="es">
<head>
    <meta charset="UTF-8">
    <title>Página de prueba</title>
</head>
<body>
<div id="main" class="full-width">
    <h1>El título de la página</h1>
    <p>Este es el primer párrafo</p>
    <p>Este es el segundo párrafo</p>
    <div id="innerDiv">
        <div class="links">
            <a href="https://pagina1.xyz/">Enlace 1</a>
            <a href="https://pagina2.xyz/">Enlace 2</a>
        </div>
        <div class="right">
            <div class="links">
                <a href="https://pagina3.xyz/">Enlace 3</a>
                <a href="https://pagina4.xyz/">Enlace 4</a>
                <p> Esto es un parrafo </p>
            </div>
        </div>
    </div>
    <div id="footer">
        <!-- El footer -->
        <p>Este párrafo está en el footer</p>
        <div class="links footer-links">
            <a href="https://pagina5.xyz/">Enlace 5</a>
        </div>
    </div>
</div>
</body>
</html>
"""
soup = BeautifulSoup(contenido, 'lxml')

# %%
footer=soup.find_all(id='footer')
print(footer)
# Out:
# [<div id="footer">
# <!-- El footer -->
# <p>Este párrafo está en el footer</p>
# <div class="links footer-links">
# <a href="https://pagina5.xyz/">Enlace 5</a>
# </div>
# </div>]

# %%
links_div=soup.find_all('div',class_="links")
print(links_div)
# Out:
# [<div class="links">
# <a href="https://pagina1.xyz/">Enlace 1</a>
# <a href="https://pagina2.xyz/">Enlace 2</a>
# </div>, <div class="links">
# <a href="https://pagina3.xyz/">Enlace 3</a>
# <a href="https://pagina4.xyz/">Enlace 4</a>
# <p> Esto es un parrafo </p>
# </div>, <div class="links footer-links">
# <a href="https://pagina5.xyz/">Enlace 5</a>
# </div>]

# %%
links_div=soup.find_all('div',class_="links footer-links")
print(links_div)
# Out:
# [<div class="links footer-links">
# <a href="https://pagina5.xyz/">Enlace 5</a>
# </div>]

# %%
from bs4 import BeautifulSoup
import requests
import csv
from datetime import datetime

# %%
url_page='https://www.bolsamadrid.es/esp/aspx/Indices/Resumen.aspx'
page=requests.get(url_page).text
soup=BeautifulSoup(page,"lxml")

# %%
tabla=soup.find('table',attrs={'id':'ctl00_Contenido_tblÍndices'})
print(tabla)

# %%
tabla=soup.find('table',attrs={'id':'ctl00_Contenido_tblÍndices'})

# %%
#tabla=soup.find('table',attrs={'id':''})

from bs4 import BeautifulSoup
import requests
import csv
from datetime import datetime

url_page='https://www.bolsamadrid.es/esp/aspx/Indices/Resumen.aspx'
page=requests.get(url_page).text
soup=BeautifulSoup(page,"lxml")

tabla=soup.find('table',attrs={'id':'ctl00_Contenido_tblÍndices'})

price=""
nroFila=0
for fila in tabla.find_all("tr"):  # <td class="DifFlSb" align="left">IBEX 35&#174;</td><td>7.916,80</td><td>8.033,10</td><td ...
  if nroFila==5:
    nro_Celda=0
    for celda in fila.find_all("td"):
      if nro_Celda==0:
        name=celda.text
        print("Indice :", name)
      if nro_Celda==6:
        fecha=celda.text
        print("Fecha :",fecha)
      nro_Celda=nro_Celda+1
  nroFila=nroFila+1
# Out:
# Indice : IBEX 35® Bancos
# Fecha : 09/09/2022

# %%
with open('bolsa_valores.csv','a') as csv_file:
  writer=csv.writer(csv_file)
  writer.writerow([name, fecha, datetime.now()])

# %%
busqueda_div=soup.find('div', attrs={'class':'TituloPag'})
print(busqueda_div.text)
# Out:
# Resumen de Índices

# %%
url_pag='https://www.bolsamadrid.es/esp/aspx/Empresas/BusqEmpresas.aspx?busq=hola'
page=requests.get(url_page).text
soup=BeautifulSoup(page,"lxml")

# %%
dato=soup.find('input',attrs={'name':'busq'}).get_text()
print(dato)

# %%
url_pag='https://www.bolsamadrid.es/esp/aspx/Empresas/BusqEmpresas.aspx?busq=dia'
page=requests.get(url_pag).text
soup=BeautifulSoup(page,"lxml")
tabla=soup.find('table',attrs={'class':'TblPort'})
print(tabla)

# %%
price=""
nroFila=0
for fila in tabla.find_all("tr"):  
  if nroFila==1:
    nro_Celda=0
    for celda in fila.find_all("td"):
      if nro_Celda==0:
        name=celda.text
        print("Indice :", name)
        enlace=celda.find('a')
        print(enlace['href'])
      if nro_Celda==2:
        price=celda.text
        print("Valor :",price)
      nro_Celda=nro_Celda+1
  nroFila=nroFila+1
# Out:
# Indice : ARKADIA FINANZAS, SICAV, S.A.
# /esp/aspx/Empresas/FichaValor.aspx?ISIN=ES0175258039&ClvEmis=75258

# %%
url_pag='https://www.bolsamadrid.es/esp/aspx/Empresas/BusqEmpresas.aspx?busq=dia'
page=requests.get(url_pag).text
soup=BeautifulSoup(page,"lxml")
tabla=soup.find('table',attrs={'class':'FrmBusq'})
print(tabla)
# Out:
# <table class="FrmBusq"><tr>
# <td align="center" class="Etiqueta">Nombre / ISIN / Ticker de la Emisora</td>
# <td align="center" class="Campo">
# <input id="ctl00_Contenido_TextoBusq" name="ctl00$Contenido$TextoBusq" type="text" value="dia"/>
#
#
#   </td>
# <td class="Buscar"><input id="ctl00_Contenido_Buscar" name="ctl00$Contenido$Buscar" onclick='javascript:WebForm_DoPostBackWithOptions(new WebForm_PostBackOptions("ctl00$Contenido$Buscar", "", true, "", "", false, false))' type="submit" value=" Buscar "/></td>
# </tr></table>

# %%
price=""
nroFila=0
for fila in tabla.find_all("tr"):  
  if nroFila==0:
    nro_Celda=0
    for celda in fila.find_all("td"):
      if nro_Celda==1:
        name=celda.text
        print("Indice :", name)
        enlace=celda.find('input')
        #enlace=celda.find('a')
        print('Valor de consulta :',enlace['value'])
      if nro_Celda==2:
        price=celda.text
        print("Valor :",price)
      nro_Celda=nro_Celda+1
  nroFila=nroFila+1
# Out:
# Indice :
#
#
#
#
# Valor de consulta : dia
# Valor :
