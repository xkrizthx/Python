# %% [markdown]
# <a href="https://colab.research.google.com/github/xkrizthx/Python/blob/python/Diplomado_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Creación de un DataFrame a partir de un fichero CSV o Excel
#
# ![image.png](data:image/png;base64,...)

# %%
import pandas as pd
df1=pd.read_csv('https://raw.githubusercontent.com/asalber/manual-python/master/datos/colesteroles.csv',sep=';',decimal=',')
print(df1.head(5))
# Out:
#                          nombre  edad sexo  peso  altura  colesterol
# 0  José Luis Martínez Izquierdo    18    H  85.0    1.79       182.0
# 1                Rosa Díaz Díaz    32    M  65.0    1.73       232.0
# 2         Javier García Sánchez    24    H   NaN    1.81       191.0
# 3           Carmen López Pinzón    35    M  65.0    1.70       200.0
# 4          Marisa López Collado    46    M  51.0    1.58       148.0

# %%
df2=pd.read_excel('/content/fichero2.xlsx',sheet_name='hoja1',header=0)
print(df2)
# Out:
#                              nombre  edad sexo   peso  altura  colesterol
# 0      José Luis Martínez Izquierdo    18    H   85.0    1.79       182.0
# 1                    Rosa Díaz Díaz    32    M   65.0    1.73       232.0
# 2             Javier García Sánchez    24    H    NaN    1.81       191.0
# 3               Carmen López Pinzón    35    M   65.0    1.70       200.0
# 4              Marisa López Collado    46    M   51.0    1.58       148.0
# 5                 Antonio Ruiz Cruz    68    H   66.0    1.74       249.0
# 6           Antonio Fernández Ocaña    51    H   62.0    1.72       276.0
# 7             Pilar Martín González    22    M   60.0    1.66         NaN
# 8              Pedro Gálvez Tenorio    35    H   90.0    1.94       241.0
# 9           Santiago Reillo Manzano    46    H   75.0    1.85       280.0
# 10            Macarena Álvarez Luna    53    M   55.0    1.62       262.0
# 11       José María de la Guía Sanz    58    H   78.0    1.87       198.0
# ...

# %% [markdown]
# # Exportación de ficheros
#
# ![image.png](data:image/png;base64,...)

# %%
df1.to_excel('/content/fichero.xlsx',sheet_name='hoja1',header=0)

# %%
df2.to_csv('/content/fichero3.csv',sep=';',index=True)

# %% [markdown]
# # Atributos de un DataFrame
#
# ![image.png](data:image/png;base64,...)

# %%
import pandas as pd
df1=pd.read_csv('https://raw.githubusercontent.com/asalber/manual-python/master/datos/colesteroles.csv',sep=';',decimal=',')
#print(df1.tail(3))
print(df1.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   nombre      14 non-null     object
#  1   edad        14 non-null     int64
#  2   sexo        14 non-null     object
#  3   peso        13 non-null     float64
#  4   altura      14 non-null     float64
#  5   colesterol  13 non-null     float64
# dtypes: float64(3), int64(1), object(2)
# memory usage: 800.0+ bytes
# None

# %%
print(df1.shape)  #Total filas y Columnas
# Out:
# (14, 6)

# %%
print(df1.size)  #Total de campos de la Matrix
# Out:
# 84

# %%
print(df1.columns)
# Out:
# Index(['nombre', 'edad', 'sexo', 'peso', 'altura', 'colesterol'], dtype='object')

# %%
print(df1.index)
# Out:
# RangeIndex(start=0, stop=14, step=1)

# %%
print(df1.dtypes)
# Out:
# nombre         object
# edad            int64
# sexo           object
# peso          float64
# altura        float64
# colesterol    float64
# dtype: object

# %%
print(df1.tail(3))
# Out:
#                              nombre  edad sexo   peso  altura  colesterol
# 11       José María de la Guía Sanz    58    H   78.0    1.87       198.0
# 12  Miguel Angel Cuadrado Gutiérrez    27    H  109.0    1.98       210.0
# 13            Carolina Rubio Moreno    20    M   61.0    1.77       194.0

# %% [markdown]
# #Renombrar los nombres de las filas y columnas
#
# ![image.png](data:image/png;base64,...)

# %%
import pandas as pd
df1=pd.read_csv('https://raw.githubusercontent.com/asalber/manual-python/master/datos/colesteroles.csv',sep=';',decimal=',')
df2=df1.rename(columns={'nombre':'nombre y apellidos','altura':'estatura'},index={0:1000,1:1001,2:1002,8:8000})
print(df2)
# Out:
#                    nombre y apellidos  edad sexo   peso  estatura  colesterol
# 1000     José Luis Martínez Izquierdo    18    H   85.0      1.79       182.0
# 1001                   Rosa Díaz Díaz    32    M   65.0      1.73       232.0
# 1002            Javier García Sánchez    24    H    NaN      1.81       191.0
# 3                 Carmen López Pinzón    35    M   65.0      1.70       200.0
# 4                Marisa López Collado    46    M   51.0      1.58       148.0
# 5                   Antonio Ruiz Cruz    68    H   66.0      1.74       249.0
# 6             Antonio Fernández Ocaña    51    H   62.0      1.72       276.0
# 7               Pilar Martín González    22    M   60.0      1.66         NaN
# 8000             Pedro Gálvez Tenorio    35    H   90.0      1.94       241.0
# 9             Santiago Reillo Manzano    46    H   75.0      1.85       280.0
# 10              Macarena Álvarez Luna    53    M   55.0      1.62       262.0
# ...

# %%
import pandas as pd
df1=pd.read_csv('https://raw.githubusercontent.com/asalber/manual-python/master/datos/colesteroles.csv',sep=';',decimal=',')
print(df1)
# Out:
#                              nombre  edad sexo   peso  altura  colesterol
# 0      José Luis Martínez Izquierdo    18    H   85.0    1.79       182.0
# 1                    Rosa Díaz Díaz    32    M   65.0    1.73       232.0
# 2             Javier García Sánchez    24    H    NaN    1.81       191.0
# 3               Carmen López Pinzón    35    M   65.0    1.70       200.0
# 4              Marisa López Collado    46    M   51.0    1.58       148.0
# 5                 Antonio Ruiz Cruz    68    H   66.0    1.74       249.0
# 6           Antonio Fernández Ocaña    51    H   62.0    1.72       276.0
# 7             Pilar Martín González    22    M   60.0    1.66         NaN
# 8              Pedro Gálvez Tenorio    35    H   90.0    1.94       241.0
# 9           Santiago Reillo Manzano    46    H   75.0    1.85       280.0
# 10            Macarena Álvarez Luna    53    M   55.0    1.62       262.0
# 11       José María de la Guía Sanz    58    H   78.0    1.87       198.0
# ...

# %%
print(df1.loc[2,'altura'])
# Out:
# 1.81

# %%
print(df1.loc[2:45,'sexo':'colesterol'])
# Out:
#    sexo   peso  altura  colesterol
# 2     H    NaN    1.81       191.0
# 3     M   65.0    1.70       200.0
# 4     M   51.0    1.58       148.0
# 5     H   66.0    1.74       249.0
# 6     H   62.0    1.72       276.0
# 7     M   60.0    1.66         NaN
# 8     H   90.0    1.94       241.0
# 9     H   75.0    1.85       280.0
# 10    M   55.0    1.62       262.0
# 11    H   78.0    1.87       198.0
# 12    H  109.0    1.98       210.0
# 13    M   61.0    1.77       194.0

# %% [markdown]
# #Reindexar un DataFrame
#
# ![image.png](data:image/png;base64,...)

# %%
import pandas as pd
df1=pd.read_csv('https://raw.githubusercontent.com/asalber/manual-python/master/datos/colesteroles.csv',sep=';',decimal=',')
print(df1)
# Out:
#                              nombre  edad sexo   peso  altura  colesterol
# 0      José Luis Martínez Izquierdo    18    H   85.0    1.79       182.0
# 1                    Rosa Díaz Díaz    32    M   65.0    1.73       232.0
# 2             Javier García Sánchez    24    H    NaN    1.81       191.0
# 3               Carmen López Pinzón    35    M   65.0    1.70       200.0
# 4              Marisa López Collado    46    M   51.0    1.58       148.0
# 5                 Antonio Ruiz Cruz    68    H   66.0    1.74       249.0
# 6           Antonio Fernández Ocaña    51    H   62.0    1.72       276.0
# 7             Pilar Martín González    22    M   60.0    1.66         NaN
# 8              Pedro Gálvez Tenorio    35    H   90.0    1.94       241.0
# 9           Santiago Reillo Manzano    46    H   75.0    1.85       280.0
# 10            Macarena Álvarez Luna    53    M   55.0    1.62       262.0
# 11       José María de la Guía Sanz    58    H   78.0    1.87       198.0
# ...

# %%
print(df1.reindex(index=[0,3,10], columns=['nombre','tension','colesterol']))
# Out:
#                           nombre  tension  colesterol
# 0   José Luis Martínez Izquierdo      NaN       182.0
# 3            Carmen López Pinzón      NaN       200.0
# 10         Macarena Álvarez Luna      NaN       262.0

# %% [markdown]
# # Acceso a los elementos de un DataFrame
#
# ![image.png](data:image/png;base64,...)

# %%
import pandas as pd
df1=pd.read_csv('https://raw.githubusercontent.com/asalber/manual-python/master/datos/colesteroles.csv',sep=';',decimal=',')
print(df1)
# Out:
#                              nombre  edad sexo   peso  altura  colesterol
# 0      José Luis Martínez Izquierdo    18    H   85.0    1.79       182.0
# 1                    Rosa Díaz Díaz    32    M   65.0    1.73       232.0
# 2             Javier García Sánchez    24    H    NaN    1.81       191.0
# 3               Carmen López Pinzón    35    M   65.0    1.70       200.0
# 4              Marisa López Collado    46    M   51.0    1.58       148.0
# 5                 Antonio Ruiz Cruz    68    H   66.0    1.74       249.0
# 6           Antonio Fernández Ocaña    51    H   62.0    1.72       276.0
# 7             Pilar Martín González    22    M   60.0    1.66         NaN
# 8              Pedro Gálvez Tenorio    35    H   90.0    1.94       241.0
# 9           Santiago Reillo Manzano    46    H   75.0    1.85       280.0
# 10            Macarena Álvarez Luna    53    M   55.0    1.62       262.0
# 11       José María de la Guía Sanz    58    H   78.0    1.87       198.0
# ...

# %%
print(df1.iloc[1,4])
# Out:
# 1.73

# %%
print(df1.iloc[1:5,2:5])
# Out:
#   sexo  peso  altura
# 1    M  65.0    1.73
# 2    H   NaN    1.81
# 3    M  65.0    1.70
# 4    M  51.0    1.58

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #Acceso a los elementos mediante nombres
#
# ![image.png](data:image/png;base64,...)

# %%
import pandas as pd
df1=pd.read_csv('https://raw.githubusercontent.com/asalber/manual-python/master/datos/colesteroles.csv',sep=';',decimal=',')
print(df1)
# Out:
#                              nombre  edad sexo   peso  altura  colesterol
# 0      José Luis Martínez Izquierdo    18    H   85.0    1.79       182.0
# 1                    Rosa Díaz Díaz    32    M   65.0    1.73       232.0
# 2             Javier García Sánchez    24    H    NaN    1.81       191.0
# 3               Carmen López Pinzón    35    M   65.0    1.70       200.0
# 4              Marisa López Collado    46    M   51.0    1.58       148.0
# 5                 Antonio Ruiz Cruz    68    H   66.0    1.74       249.0
# 6           Antonio Fernández Ocaña    51    H   62.0    1.72       276.0
# 7             Pilar Martín González    22    M   60.0    1.66         NaN
# 8              Pedro Gálvez Tenorio    35    H   90.0    1.94       241.0
# 9           Santiago Reillo Manzano    46    H   75.0    1.85       280.0
# 10            Macarena Álvarez Luna    53    M   55.0    1.62       262.0
# 11       José María de la Guía Sanz    58    H   78.0    1.87       198.0
# ...

# %%
#print(df1.loc[2,('nombre','colesterol')])
print(df1.loc[2,'colesterol'])
# Out:
# 191.0

# %%
print(df1.loc[2:5,('nombre','colesterol')])
# Out:
#                   nombre  colesterol
# 2  Javier García Sánchez       191.0
# 3    Carmen López Pinzón       200.0
# 4   Marisa López Collado       148.0
# 5      Antonio Ruiz Cruz       249.0

# %%
print(df1.loc[12:13,('nombre','colesterol','altura')])
# Out:
#                              nombre  colesterol  altura
# 12  Miguel Angel Cuadrado Gutiérrez       210.0    1.98
# 13            Carolina Rubio Moreno       194.0    1.77

# %% [markdown]
# #Operaciones con las columnas de un DataFrame
# ![image.png](data:image/png;base64,...)

# %%
import pandas as pd
df1=pd.read_csv('https://raw.githubusercontent.com/asalber/manual-python/master/datos/colesteroles.csv',sep=';',decimal=',')
print(df1)
# Out:
#                              nombre  edad sexo   peso  altura  colesterol
# 0      José Luis Martínez Izquierdo    18    H   85.0    1.79       182.0
# 1                    Rosa Díaz Díaz    32    M   65.0    1.73       232.0
# 2             Javier García Sánchez    24    H    NaN    1.81       191.0
# 3               Carmen López Pinzón    35    M   65.0    1.70       200.0
# 4              Marisa López Collado    46    M   51.0    1.58       148.0
# 5                 Antonio Ruiz Cruz    68    H   66.0    1.74       249.0
# 6           Antonio Fernández Ocaña    51    H   62.0    1.72       276.0
# 7             Pilar Martín González    22    M   60.0    1.66         NaN
# 8              Pedro Gálvez Tenorio    35    H   90.0    1.94       241.0
# 9           Santiago Reillo Manzano    46    H   75.0    1.85       280.0
# 10            Macarena Álvarez Luna    53    M   55.0    1.62       262.0
# 11       José María de la Guía Sanz    58    H   78.0    1.87       198.0
# ...

# %%
df1['diabetes']=pd.Series([False,False,True,False,True])
print(df1)
# Out:
#                              nombre  edad sexo   peso  altura  colesterol  \
# 0      José Luis Martínez Izquierdo    18    H   85.0    1.79       182.0
# 1                    Rosa Díaz Díaz    32    M   65.0    1.73       232.0
# 2             Javier García Sánchez    24    H    NaN    1.81       191.0
# 3               Carmen López Pinzón    35    M   65.0    1.70       200.0
# 4              Marisa López Collado    46    M   51.0    1.58       148.0
# 5                 Antonio Ruiz Cruz    68    H   66.0    1.74       249.0
# 6           Antonio Fernández Ocaña    51    H   62.0    1.72       276.0
# 7             Pilar Martín González    22    M   60.0    1.66         NaN
# 8              Pedro Gálvez Tenorio    35    H   90.0    1.94       241.0
# 9           Santiago Reillo Manzano    46    H   75.0    1.85       280.0
# 10            Macarena Álvarez Luna    53    M   55.0    1.62       262.0
# 11       José María de la Guía Sanz    58    H   78.0    1.87       198.0
# ...

# %% [markdown]
# #Operaciones sobre columnas
#
# ![image.png](data:image/png;base64,...)

# %%
import pandas as pd
df1=pd.read_csv('https://raw.githubusercontent.com/asalber/manual-python/master/datos/colesteroles.csv',sep=';',decimal=',')
print(df1)
# Out:
#                              nombre  edad sexo   peso  altura  colesterol
# 0      José Luis Martínez Izquierdo    18    H   85.0    1.79       182.0
# 1                    Rosa Díaz Díaz    32    M   65.0    1.73       232.0
# 2             Javier García Sánchez    24    H    NaN    1.81       191.0
# 3               Carmen López Pinzón    35    M   65.0    1.70       200.0
# 4              Marisa López Collado    46    M   51.0    1.58       148.0
# 5                 Antonio Ruiz Cruz    68    H   66.0    1.74       249.0
# 6           Antonio Fernández Ocaña    51    H   62.0    1.72       276.0
# 7             Pilar Martín González    22    M   60.0    1.66         NaN
# 8              Pedro Gálvez Tenorio    35    H   90.0    1.94       241.0
# 9           Santiago Reillo Manzano    46    H   75.0    1.85       280.0
# 10            Macarena Álvarez Luna    53    M   55.0    1.62       262.0
# 11       José María de la Guía Sanz    58    H   78.0    1.87       198.0
# ...

# %%
df1=df1['altura']*100
print(df1)
# Out:
# 0     179.0
# 1     173.0
# 2     181.0
# 3     170.0
# 4     158.0
# 5     174.0
# 6     172.0
# 7     166.0
# 8     194.0
# 9     185.0
# 10    162.0
# 11    187.0
# 12    198.0
# 13    177.0
# Name: altura, dtype: float64

# %%
print(df1)
# Out:
# 0     179.0
# 1     173.0
# 2     181.0
# 3     170.0
# 4     158.0
# 5     174.0
# 6     172.0
# 7     166.0
# 8     194.0
# 9     185.0
# 10    162.0
# 11    187.0
# 12    198.0
# 13    177.0
# Name: altura, dtype: float64

# %% [markdown]
# #Aplicar funciones a Columas
# ![image.png](data:image/png;base64,...)

# %%
import pandas as pd
df1=pd.read_csv('https://raw.githubusercontent.com/asalber/manual-python/master/datos/colesteroles.csv',sep=';',decimal=',')
print(df1)
# Out:
#                              nombre  edad sexo   peso  altura  colesterol
# 0      José Luis Martínez Izquierdo    18    H   85.0    1.79       182.0
# 1                    Rosa Díaz Díaz    32    M   65.0    1.73       232.0
# 2             Javier García Sánchez    24    H    NaN    1.81       191.0
# 3               Carmen López Pinzón    35    M   65.0    1.70       200.0
# 4              Marisa López Collado    46    M   51.0    1.58       148.0
# 5                 Antonio Ruiz Cruz    68    H   66.0    1.74       249.0
# 6           Antonio Fernández Ocaña    51    H   62.0    1.72       276.0
# 7             Pilar Martín González    22    M   60.0    1.66         NaN
# 8              Pedro Gálvez Tenorio    35    H   90.0    1.94       241.0
# 9           Santiago Reillo Manzano    46    H   75.0    1.85       280.0
# 10            Macarena Álvarez Luna    53    M   55.0    1.62       262.0
# 11       José María de la Guía Sanz    58    H   78.0    1.87       198.0
# ...

# %%
import pandas as pd
from math import *
print(df1['edad'].apply(sqrt))
# Out:
# 0     4.242641
# 1     5.656854
# 2     4.898979
# 3     5.916080
# 4     6.782330
# 5     8.246211
# 6     7.141428
# 7     4.690416
# 8     5.916080
# 9     6.782330
# 10    7.280110
# 11    7.615773
# 12    5.196152
# 13    4.472136
# Name: edad, dtype: float64

# %% [markdown]
# # Resumen descriptivo de un DataFrame
#
# ![image.png](data:image/png;base64,...)

# %%
import pandas as pd
df1=pd.read_csv('https://raw.githubusercontent.com/asalber/manual-python/master/datos/colesteroles.csv',sep=';',decimal=',')
print(df1)
# Out:
#                              nombre  edad sexo   peso  altura  colesterol
# 0      José Luis Martínez Izquierdo    18    H   85.0    1.79       182.0
# 1                    Rosa Díaz Díaz    32    M   65.0    1.73       232.0
# 2             Javier García Sánchez    24    H    NaN    1.81       191.0
# 3               Carmen López Pinzón    35    M   65.0    1.70       200.0
# 4              Marisa López Collado    46    M   51.0    1.58       148.0
# 5                 Antonio Ruiz Cruz    68    H   66.0    1.74       249.0
# 6           Antonio Fernández Ocaña    51    H   62.0    1.72       276.0
# 7             Pilar Martín González    22    M   60.0    1.66         NaN
# 8              Pedro Gálvez Tenorio    35    H   90.0    1.94       241.0
# 9           Santiago Reillo Manzano    46    H   75.0    1.85       280.0
# 10            Macarena Álvarez Luna    53    M   55.0    1.62       262.0
# 11       José María de la Guía Sanz    58    H   78.0    1.87       198.0
# ...

# %%
df1.count()
# Out:
# nombre        14
# edad          14
# sexo          14
# peso          13
# altura        14
# colesterol    13
# dtype: int64

# %%
df1.sum()
# Out:
# nombre        José Luis Martínez IzquierdoRosa Díaz DíazJavi...
# edad                                                        535
# sexo                                             HMHMMHHMHHMHHM
# peso                                                      922.0
# altura                                                    24.76
# colesterol                                               2863.0
# dtype: object

# %%
df1.cumsum()
# Out:
#                                                nombre  edad            sexo  \
# 0                        José Luis Martínez Izquierdo    18               H
# 1          José Luis Martínez IzquierdoRosa Díaz Díaz    50              HM
# 2   José Luis Martínez IzquierdoRosa Díaz DíazJavi...    74             HMH
# 3   José Luis Martínez IzquierdoRosa Díaz DíazJavi...   109            HMHM
# 4   José Luis Martínez IzquierdoRosa Díaz DíazJavi...   155           HMHMM
# 5   José Luis Martínez IzquierdoRosa Díaz DíazJavi...   223          HMHMMH
# 6   José Luis Martínez IzquierdoRosa Díaz DíazJavi...   274         HMHMMHH
# 7   José Luis Martínez IzquierdoRosa Díaz DíazJavi...   296        HMHMMHHM
# 8   José Luis Martínez IzquierdoRosa Díaz DíazJavi...   331       HMHMMHHMH
# 9   José Luis Martínez IzquierdoRosa Díaz DíazJavi...   377      HMHMMHHMHH
# 10  José Luis Martínez IzquierdoRosa Díaz DíazJavi...   430     HMHMMHHMHHM
# ...

# %%
df1.min()
# Out:
# nombre        Antonio Fernández Ocaña
# edad                               18
# sexo                                H
# peso                             51.0
# altura                           1.58
# colesterol                      148.0
# dtype: object

# %%
df1.max()
# Out:
# nombre        Santiago Reillo Manzano
# edad                               68
# sexo                                M
# peso                            109.0
# altura                           1.98
# colesterol                      280.0
# dtype: object

# %%
df1.mean()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# edad           38.214286
# peso           70.923077
# altura          1.768571
# colesterol    220.230769
# dtype: float64

# %%
df1.std()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# edad          15.621379
# peso          16.126901
# altura         0.115016
# colesterol    39.847948
# dtype: float64

# %%
df1.describe()
# Out:
#             edad        peso     altura  colesterol
# count  14.000000   13.000000  14.000000   13.000000
# mean   38.214286   70.923077   1.768571  220.230769
# std    15.621379   16.126901   0.115016   39.847948
# min    18.000000   51.000000   1.580000  148.000000
# 25%    24.750000   61.000000   1.705000  194.000000
# 50%    35.000000   65.000000   1.755000  210.000000
# 75%    49.750000   78.000000   1.840000  249.000000
# max    68.000000  109.000000   1.980000  280.000000

# %%
df1.describe(include=object)
# Out:
#                               nombre sexo
# count                             14   14
# unique                            14    2
# top     José Luis Martínez Izquierdo    H
# freq                               1    8

# %% [markdown]
# #Eliminar Columnas de un Dataframe
#
# ![image.png](data:image/png;base64,...)

# %%
import pandas as pd
df1=pd.read_csv('https://raw.githubusercontent.com/asalber/manual-python/master/datos/colesteroles.csv',sep=';',decimal=',')
print(df1)
# Out:
#                              nombre  edad sexo   peso  altura  colesterol
# 0      José Luis Martínez Izquierdo    18    H   85.0    1.79       182.0
# 1                    Rosa Díaz Díaz    32    M   65.0    1.73       232.0
# 2             Javier García Sánchez    24    H    NaN    1.81       191.0
# 3               Carmen López Pinzón    35    M   65.0    1.70       200.0
# 4              Marisa López Collado    46    M   51.0    1.58       148.0
# 5                 Antonio Ruiz Cruz    68    H   66.0    1.74       249.0
# 6           Antonio Fernández Ocaña    51    H   62.0    1.72       276.0
# 7             Pilar Martín González    22    M   60.0    1.66         NaN
# 8              Pedro Gálvez Tenorio    35    H   90.0    1.94       241.0
# 9           Santiago Reillo Manzano    46    H   75.0    1.85       280.0
# 10            Macarena Álvarez Luna    53    M   55.0    1.62       262.0
# 11       José María de la Guía Sanz    58    H   78.0    1.87       198.0
# ...

# %%
edad=df1.pop('edad')
print(edad)
# Out:
# 0     18
# 1     32
# 2     24
# 3     35
# 4     46
# 5     68
# 6     51
# 7     22
# 8     35
# 9     46
# 10    53
# 11    58
# 12    27
# 13    20
# Name: edad, dtype: int64

# %%
print(df1)
# Out:
#                              nombre sexo   peso  altura  colesterol
# 0      José Luis Martínez Izquierdo    H   85.0    1.79       182.0
# 1                    Rosa Díaz Díaz    M   65.0    1.73       232.0
# 2             Javier García Sánchez    H    NaN    1.81       191.0
# 3               Carmen López Pinzón    M   65.0    1.70       200.0
# 4              Marisa López Collado    M   51.0    1.58       148.0
# 5                 Antonio Ruiz Cruz    H   66.0    1.74       249.0
# 6           Antonio Fernández Ocaña    H   62.0    1.72       276.0
# 7             Pilar Martín González    M   60.0    1.66         NaN
# 8              Pedro Gálvez Tenorio    H   90.0    1.94       241.0
# 9           Santiago Reillo Manzano    H   75.0    1.85       280.0
# 10            Macarena Álvarez Luna    M   55.0    1.62       262.0
# 11       José María de la Guía Sanz    H   78.0    1.87       198.0
# 12  Miguel Angel Cuadrado Gutiérrez    H  109.0    1.98       210.0
# ...

# %% [markdown]
# Taller: Realizar:
#
# Al dataframe original
# import pandas as pd
# df1=pd.read_csv('https://raw.githubusercontent.com/asalber/manual-python/master/datos/colesteroles.csv',sep=';',decimal=',')
# print(df1)
#
# Eliminen la columnas colesterol y peso --> guardar en un archivo de Excel
#
# "Estadomedico.xlsx

# %%
import pandas as pd
df1=pd.read_csv('https://raw.githubusercontent.com/asalber/manual-python/master/datos/colesteroles.csv',sep=';',decimal=',')
print(df1)
# Out:
#                              nombre  edad sexo   peso  altura  colesterol
# 0      José Luis Martínez Izquierdo    18    H   85.0    1.79       182.0
# 1                    Rosa Díaz Díaz    32    M   65.0    1.73       232.0
# 2             Javier García Sánchez    24    H    NaN    1.81       191.0
# 3               Carmen López Pinzón    35    M   65.0    1.70       200.0
# 4              Marisa López Collado    46    M   51.0    1.58       148.0
# 5                 Antonio Ruiz Cruz    68    H   66.0    1.74       249.0
# 6           Antonio Fernández Ocaña    51    H   62.0    1.72       276.0
# 7             Pilar Martín González    22    M   60.0    1.66         NaN
# 8              Pedro Gálvez Tenorio    35    H   90.0    1.94       241.0
# 9           Santiago Reillo Manzano    46    H   75.0    1.85       280.0
# 10            Macarena Álvarez Luna    53    M   55.0    1.62       262.0
# 11       José María de la Guía Sanz    58    H   78.0    1.87       198.0
# ...

# %%
df1.drop([10,13])
# Out:
#                              nombre  edad sexo   peso  altura  colesterol
# 0      José Luis Martínez Izquierdo    18    H   85.0    1.79       182.0
# 1                    Rosa Díaz Díaz    32    M   65.0    1.73       232.0
# 2             Javier García Sánchez    24    H    NaN    1.81       191.0
# 3               Carmen López Pinzón    35    M   65.0    1.70       200.0
# 4              Marisa López Collado    46    M   51.0    1.58       148.0
# 5                 Antonio Ruiz Cruz    68    H   66.0    1.74       249.0
# 6           Antonio Fernández Ocaña    51    H   62.0    1.72       276.0
# 7             Pilar Martín González    22    M   60.0    1.66         NaN
# 8              Pedro Gálvez Tenorio    35    H   90.0    1.94       241.0
# 9           Santiago Reillo Manzano    46    H   75.0    1.85       280.0
# 11       José María de la Guía Sanz    58    H   78.0    1.87       198.0
# 12  Miguel Angel Cuadrado Gutiérrez    27    H  109.0    1.98       210.0
